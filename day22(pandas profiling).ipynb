# %% [markdown]
# # Pandas Profilers

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
# %pip install pandas-profiling

# %%
pip install -U ydata-profiling

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 253.97it/s]00:00, 23.59it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:03<00:00, 11.78it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  4.52it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 59.31it/s]
